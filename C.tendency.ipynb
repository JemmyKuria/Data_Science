# %%
#Central value for data distribution
import matplotlib.pyplot as plt
x=[ 68.03955366,  63.50358342,  99.79134537,  92.98739 ,120.20321147]
bins = 5

plt.hist(x, bins=bins, edgecolor="black", color="#00C8AD")
plt.title("Weights");
